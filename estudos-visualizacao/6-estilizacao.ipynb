# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("WorldCups.csv", index_col=0, parse_dates=True)
df = df.iloc[:, [1, 5, 7, 8]]
first_10_wc = df.head(10)

# %%
# estilo da figura
sns.set_style("dark")

plt.figure(figsize=(12, 6))
sns.lineplot(data=first_10_wc)
# Out:
# <Axes: xlabel='Year'>
